# %% [markdown]
# # Inheritance in Class
# All properties from parent class will be transferred to child class

# %% [markdown]
# ![Alt text](image.png)

# %% [markdown]
# ## Types of Inheritance
# 1. Single Inheritance
# 2. Multilevel Inheritance
# 3. Hierarhcical Inheritance

# %% [markdown]
# ![Alt text](image-1.png)

# %% [markdown]
# ## 1. Single Inheritance

# %%
class Person:
    def __init__(self,name,age):
        self.name = name
        self.age = age
    def introduce(self):
        print(f'Hi my name is {self.name},I am currently {self.age} years old.')

# %%
class Employee(Person):
    def __init__(self, name, age,company):
        super().__init__(name, age)
        self.company = company
    def work(self):
        super().introduce()
        print(f'I work for {self.company}')

# %%
p1 = Person('mohit',21)

# %%
p2 = Person('raju',34)

# %%
p2.name
# Out:
# 'raju'

# %%
p1.age
# Out:
# 21

# %%
p2.age
# Out:
# 34

# %%
p2.introduce()
# Out:
# Hi my name is raju,I am currently 34 years old.

# %%
p1.introduce()
# Out:
# Hi my name is mohit,I am currently 21 years old.

# %%
p1.work()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# d:\vs code mohit\repository\Advance Python\Session 5 Inheritance\Inheritance.ipynb Cell 15 line 1
# ----> <a href='vscode-notebook-cell:/d%3A/vs%20code%20mohit/repository/Advance%20Python/Session%205%20Inheritance/Inheritance.ipynb#X16sZmlsZQ%3D%3D?line=0'>1</a> p1.work()
#
# AttributeError: 'Person' object has no attribute 'work'

# %%
e1 = Employee('Mohit',21,'Kia')

# %%
e1.introduce()
# Out:
# Hi my name is Mohit,I am currently 21 years old.

# %%
e1.name
# Out:
# 'Mohit'

# %%
e1.company
# Out:
# 'Kia'

# %%
e1.age
# Out:
# 21

# %%
e1.work()
# Out:
# Hi my name is Mohit,I am currently 21 years old.
# I work for Kia

# %%
e1.introduce()
# Out:
# Hi my name is Mohit,I am currently 21 years old.

# %%
e1.work()
# Out:
# Hi my name is Mohit,I am currently 21 years old.
# I work for Kia

# %%
p1.work()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# d:\vs code mohit\repository\Advance Python\Session 5 Inheritance\Inheritance.ipynb Cell 24 line 1
# ----> <a href='vscode-notebook-cell:/d%3A/vs%20code%20mohit/repository/Advance%20Python/Session%205%20Inheritance/Inheritance.ipynb#X31sZmlsZQ%3D%3D?line=0'>1</a> p1.work()
#
# AttributeError: 'Person' object has no attribute 'work'

# %%
type(p1)
# Out:
# __main__.Person

# %%
type(e1)
# Out:
# __main__.Employee

# %% [markdown]
# ## 2. Multiple Inheritance

# %%
class Employee:
    def __init__(self,name,emp_id):
        self.name = name
        self.emp_id = emp_id
    def get_employee_info(self):
        print(f'Employee Name : {self.name}, Employee Id : {self.emp_id}')

# %%
class Manager(Employee):
    def __init__(self, name, emp_id,department):
        super().__init__(name, emp_id)
        self.department = department
    def get_manager_info(self):
        self.get_employee_info()
        print(f'Manager Department : {self.department}')

# %%
class ProjectManager(Manager):
    def __init__(self, name, emp_id, department,project):
        super().__init__(name, emp_id, department)
        self.project = project
    def get_projectm_info(self):
        self.get_manager_info()
        print(f'Project Name :{self.project}')

# %%
e1 = Employee('utkarsh',101)

# %%
m1 = Manager('Raman',102,'Engg')

# %%
pm1 = ProjectManager('Mohit',103,'HR','Daisy')

# %%
m1.get_employee_info()
# Out:
# Employee Name : Raman, Employee Id : 102

# %%
e1.emp_id
# Out:
# 101

# %%
m1.get_manager_info()
# Out:
# Employee Name : Raman, Employee Id : 102
# Manager Department : Engg

# %%
pm1.get_manager_info()
# Out:
# Employee Name : Mohit, Employee Id : 103
# Manager Department : HR

# %%
pm1.get_projectm_info()
# Out:
# Employee Name : Mohit, Employee Id : 103
# Manager Department : HR
# Project Name :Daisy

# %%
pm1.name
# Out:
# 'Mohit'

# %%
e1.emp_id
# Out:
# 101

# %%
m1.name
# Out:
# 'Raman'

# %%
m2 = ProjectManager('Rushikesh',106,'HR','Rahim')

# %%
m2.name
# Out:
# 'Rushikesh'

# %%
m2.age
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# d:\vs code mohit\repository\Advance Python\Session 5 Inheritance\Inheritance.ipynb Cell 44 line 1
# ----> <a href='vscode-notebook-cell:/d%3A/vs%20code%20mohit/repository/Advance%20Python/Session%205%20Inheritance/Inheritance.ipynb#X61sZmlsZQ%3D%3D?line=0'>1</a> m2.age
#
# AttributeError: 'ProjectManager' object has no attribute 'age'

# %%
m2.department
# Out:
# 'HR'

# %%
m2.project
# Out:
# 'Rahim'

# %%
m2.emp_id
# Out:
# 106

# %%
m2.get_employee_info()
# Out:
# Employee Name : Rushikesh, Employee Id : 106

# %%
m2.get_manager_info()
# Out:
# Employee Name : Rushikesh, Employee Id : 106
# Manager Department : HR

# %%
m2.get_projectm_info()
# Out:
# Employee Name : Rushikesh, Employee Id : 106
# Manager Department : HR
# Project Name :Rahim

# %% [markdown]
# ## 3. Hierarhcical Inheritance

# %% [markdown]
# ![Alt text](image-2.png)

# %%
class vehicle:
    def __init__(self,speed,direction):
        self.speed = speed
        self.direction = direction
    def accelerate(self):
        self.speed = self.speed+10
        print(f'Vehicles speed increased by 10, current speed: {self.speed}')
    def turn(self,new_dir):
        self.direction = new_dir
        print(f'Vehicles direction changes to {self.direction}')

# %%
class car(vehicle):
    def __init__(self, speed, direction,num_doors):
        super().__init__(speed, direction)
        self.num_doors = num_doors
    def open_doors(self):
        print(f'Car door is Opened')
    def close_door(self):
        print(f'car door is closed')

# %%
class bicycle(vehicle):
    def __init__(self, speed, direction,num_gears,frame_size):
        super().__init__(speed, direction)
        self.num_gears = num_gears
        self.frame_size = frame_size
    def shift_gear(self):
        print(f'Bicycle gear shifted')
    def adjust_seat(self):
        print(f'Bicycle seat ajusted')

# %%
v1 = vehicle(70, 'North')

# %%
v1.speed
# Out:
# 90

# %%
v1.accelerate()
# Out:
# Vehicles speed increased by 10, current speed: 80

# %%
v1.direction
# Out:
# 'North'

# %%
v1.turn('west')
# Out:
# Vehicles direction changes to west

# %%
v1.accelerate()
# Out:
# Vehicles speed increased by 10, current speed: 90

# %%
v1.speed
# Out:
# 90

# %%
v1.accelerate()
# Out:
# Vehicles speed increased by 10, current speed: 100

# %%
v1.direction
# Out:
# 'west'

# %%
v1.turn('south')
# Out:
# Vehicles direction changes to south

# %%
v1.direction
# Out:
# 'south'

# %%
c1 = car(50, 'South', 4)

# %%
c1.speed
# Out:
# 50

# %%
c1.direction
# Out:
# 'South'

# %%
c1.num_doors
# Out:
# 4

# %%
c1.open_doors()
# Out:
# Car door is Opened

# %%
c1.close_door()
# Out:
# car door is closed

# %%
c1.num_doors
# Out:
# 4

# %%
c1.accelerate()
# Out:
# Vehicles speed increased by 10, current speed: 60

# %%
c1.accelerate()
# Out:
# Vehicles speed increased by 10, current speed: 70

# %%
c1.turn('north')
# Out:
# Vehicles direction changes to north

# %%
c1.direction
# Out:
# 'north'

# %%
c1.shift_gear()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# d:\vs code mohit\repository\Advance Python\Session 5 Inheritance\Inheritance.ipynb Cell 78 line 1
# ----> <a href='vscode-notebook-cell:/d%3A/vs%20code%20mohit/repository/Advance%20Python/Session%205%20Inheritance/Inheritance.ipynb#Y144sZmlsZQ%3D%3D?line=0'>1</a> c1.shift_gear()
#
# AttributeError: 'car' object has no attribute 'shift_gear'

# %%
b1 = bicycle(10, 'West', 28, 'L')

# %%
b1.frame_size
# Out:
# 'L'

# %%
b1.direction
# Out:
# 'West'

# %%
b1.speed
# Out:
# 10

# %%
b1.shift_gear()
# Out:
# Bicycle gear shifted

# %%
b1.num_gears
# Out:
# 28

# %%
b1.adjust_seat()
# Out:
# Bicycle seat ajusted

# %%
b1.num_doors
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# d:\vs code mohit\repository\Advance Python\Session 5 Inheritance\Inheritance.ipynb Cell 86 line 1
# ----> <a href='vscode-notebook-cell:/d%3A/vs%20code%20mohit/repository/Advance%20Python/Session%205%20Inheritance/Inheritance.ipynb#Y155sZmlsZQ%3D%3D?line=0'>1</a> b1.num_doors
#
# AttributeError: 'bicycle' object has no attribute 'num_doors'

# %%
b1.accelerate()
# Out:
# Vehicles speed increased by 10, current speed: 20

# %%
b1.turn('north')
# Out:
# Vehicles direction changes to north

# %%
b1.open_door()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# d:\vs code mohit\repository\Advance Python\Session 5 Inheritance\Inheritance.ipynb Cell 87 line 1
# ----> <a href='vscode-notebook-cell:/d%3A/vs%20code%20mohit/repository/Advance%20Python/Session%205%20Inheritance/Inheritance.ipynb#Y156sZmlsZQ%3D%3D?line=0'>1</a> b1.open_door()
#
# AttributeError: 'bicycle' object has no attribute 'open_door'

# %% [markdown]
# # Complete
