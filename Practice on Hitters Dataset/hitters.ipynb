# %% [markdown]
# ## Hittters Dataset:-

# %%
from warnings import filterwarnings
filterwarnings('ignore')

# %% [markdown]
# ## Read the dataframe

# %%
import pandas as pd
df = pd.read_csv('hitters.csv')

# %%
df.head()
# Out:
#                Name  AtBat  Hits  HmRun  Runs  RBI  Walks  Years  CAtBat  \
# 0     Andy Allanson    293    66      1    30   29     14      1     293
# 1        Alan Ashby    315    81      7    24   38     39     14    3449
# 2       Alvin Davis    479   130     18    66   72     76      3    1624
# 3      Andre Dawson    496   141     20    65   78     37     11    5628
# 4  Andres Galarraga    321    87     10    39   42     30      2     396
#
#    CHits  ...  CRuns  CRBI  CWalks  League Division PutOuts  Assists  Errors  \
# 0     66  ...     30    29      14       A        E     446       33      20
# 1    835  ...    321   414     375       N        W     632       43      10
# 2    457  ...    224   266     263       A        W     880       82      14
# 3   1575  ...    828   838     354       N        E     200       11       3
# 4    101  ...     48    46      33       N        E     805       40       4
#
#    Salary  NewLeague
# 0     NaN          A
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 322 entries, 0 to 321
# Data columns (total 21 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Name       322 non-null    object
#  1   AtBat      322 non-null    int64
#  2   Hits       322 non-null    int64
#  3   HmRun      322 non-null    int64
#  4   Runs       322 non-null    int64
#  5   RBI        322 non-null    int64
#  6   Walks      322 non-null    int64
#  7   Years      322 non-null    int64
#  8   CAtBat     322 non-null    int64
#  9   CHits      322 non-null    int64
#  10  CHmRun     322 non-null    int64
#  11  CRuns      322 non-null    int64
#  12  CRBI       322 non-null    int64
#  13  CWalks     322 non-null    int64
#  14  League     322 non-null    object
#  15  Division   322 non-null    object
#  16  PutOuts    322 non-null    int64
#  17  Assists    322 non-null    int64
#  18  Errors     322 non-null    int64
#  19  Salary     263 non-null    float64
# ...

# %% [markdown]
# ## 1.Find out no of missing values in each column

# %%
s = df.isna().sum()
s[s>0]
# Out:
# Salary    59
# dtype: int64

# %%
mn_s = df['Salary'].mean()

# %%
mns = round(mn_s,3)

# %%
mns
# Out:
# 535.926

# %%
df['Salary'] = df['Salary'].fillna(mns)

# %%
df.isna().sum()
# Out:
# Name         0
# AtBat        0
# Hits         0
# HmRun        0
# Runs         0
# RBI          0
# Walks        0
# Years        0
# CAtBat       0
# CHits        0
# CHmRun       0
# CRuns        0
# CRBI         0
# CWalks       0
# League       0
# Division     0
# PutOuts      0
# Assists      0
# Errors       0
# Salary       0
# NewLeague    0
# dtype: int64

# %% [markdown]
# ## 2. Find of people who have batted for more than 400 matches

# %%
df[df['AtBat']>400][['Name']]
# Out:
#                 Name
# 2        Alvin Davis
# 3       Andre Dawson
# 5    Alfredo Griffin
# 9     Andre Thornton
# 10     Alan Trammell
# ..               ...
# 317     Willie McGee
# 318  Willie Randolph
# 319   Wayne Tolleson
# 320    Willie Upshaw
# 321    Willie Wilson
#
# [151 rows x 1 columns]

# %% [markdown]
# ## 3. Find out the name of the player who has hit max home runs

# %%
# Approch 1:-
df.sort_values(by='CHmRun')[['Name']].head(1)
# Out:
#             Name
# 250  Ricky Jones

# %%
# Approch 2:-
df['CHmRun'].max()
# Out:
# 548

# %%
#Approch 3:-
df[df['CHmRun']==548][['Name']]
# Out:
#                Name
# 249  Reggie Jackson

# %%
# Approch4:- 
df.sort_values('CHmRun').tail(1)[['Name']]
# Out:
#                Name
# 249  Reggie Jackson

# %% [markdown]
# ## 4. Find out league wise total number of players

# %%
# Approch 1:-
df['League'].value_counts()
# Out:
# League
# A    175
# N    147
# Name: count, dtype: int64

# %%
# Approch 2:-
df.groupby(by='League').count()[['Name']]
# Out:
#         Name
# League
# A        175
# N        147

# %% [markdown]
# ## 5. Find out division wise total amount of salary invested

# %%
df.groupby('Division').sum()[['Salary']]
# Out:
#              Salary
# Division
# E         95536.934
# W         77031.207

# %% [markdown]
# ## 6. Find out five most senior Players

# %%
# Approch 1:-
df.sort_values('Years').tail(5)[['Name','Years']]
# Out:
#                Name  Years
# 306     Ted Simmons     19
# 121   Graig Nettles     20
# 249  Reggie Jackson     20
# 302      Tony Perez     23
# 236       Pete Rose     24

# %%
# Approch 2:-
A = df.sort_values('Years',ascending=False).head(5)[['Name','Years']]
A.index = [1,2,3,4,5]

# %%
A
# Out:
#              Name  Years
# 1       Pete Rose     24
# 2      Tony Perez     23
# 3   Graig Nettles     20
# 4  Reggie Jackson     20
# 5     Ted Simmons     19

# %% [markdown]
# ## B. Cars Dataset:-

# %%
df2 = pd.read_csv('Cars93.csv')

# %%
df2.head()
# Out:
#    id Manufacturer    Model     Type  Min.Price  Price  Max.Price  MPG.city  \
# 0   1        Acura  Integra    Small       12.9   15.9       18.8        25
# 1   2        Acura   Legend  Midsize       29.2   33.9       38.7        18
# 2   3         Audi       90  Compact       25.9   29.1       32.3        20
# 3   4         Audi      100  Midsize       30.8   37.7       44.6        19
# 4   5          BMW     535i  Midsize       23.7   30.0       36.2        22
#
#    MPG.highway             AirBags  ... Passengers Length  Wheelbase  Width  \
# 0           31                 NaN  ...          5    177        102     68
# 1           25  Driver & Passenger  ...          5    195        115     71
# 2           26         Driver only  ...          5    180        102     67
# 3           26                 NaN  ...          6    193        106     70
# 4           30         Driver only  ...          4    186        109     69
#
# ...

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 93 entries, 0 to 92
# Data columns (total 28 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   id                  93 non-null     int64
#  1   Manufacturer        93 non-null     object
#  2   Model               93 non-null     object
#  3   Type                93 non-null     object
#  4   Min.Price           93 non-null     float64
#  5   Price               93 non-null     float64
#  6   Max.Price           93 non-null     float64
#  7   MPG.city            93 non-null     int64
#  8   MPG.highway         93 non-null     int64
#  9   AirBags             56 non-null     object
#  10  DriveTrain          93 non-null     object
#  11  Cylinders           93 non-null     object
#  12  EngineSize          93 non-null     float64
#  13  Horsepower          93 non-null     int64
#  14  RPM                 93 non-null     int64
# ...

# %%
a =df2.isna().sum()

# %%
a[a>0]
# Out:
# AirBags           37
# Rear.seat.room     2
# Luggage.room      11
# dtype: int64

# %%
df2['AirBags'].value_counts()
# Out:
# AirBags
# Driver only           42
# Driver & Passenger    14
# Name: count, dtype: int64

# %%
df2['AirBags'].fillna('None')
# Out:
# 0                   None
# 1     Driver & Passenger
# 2            Driver only
# 3                   None
# 4            Driver only
#              ...
# 88                  None
# 89                  None
# 90                  None
# 91           Driver only
# 92    Driver & Passenger
# Name: AirBags, Length: 93, dtype: object

# %%
b = df2.isna().sum()
b[b>0]
# Out:
# AirBags    37
# dtype: int64

# %%
df2.dtypes['Rear.seat.room']
# Out:
# dtype('float64')

# %%
mn = df2[['Rear.seat.room','Luggage.room']].mean()

# %%
df2[['Rear.seat.room','Luggage.room']] = df2[['Rear.seat.room','Luggage.room']].fillna(mn)

# %%
c = df2.isna().sum()

# %%
c[c>0]
# Out:
# AirBags    37
# dtype: int64

# %%
df2['Luggage.room'].isna().sum()
# Out:
# 0

# %% [markdown]
# ## 1. Find out car having highest Mileage in City

# %%
df2.sort_values('MPG.city').tail(1)[['Manufacturer','Model','Type','MPG.city','Price']]
# Out:
#    Manufacturer  Model   Type  MPG.city  Price
# 38          Geo  Metro  Small        46    8.4

# %% [markdown]
# ## 2. Find out Models of cars which are Having Price Values between 17 and 25

# %%
Model = df2[(df2['Price']>17) & (df2['Price']<25)][['Manufacturer','Model','Price','Type']]

# %%
Model_Price = Model.sort_values('Price')
Model_Price.index = range(1,28,1)

# %%
Model_Price
# Out:
#    Manufacturer           Model  Price     Type
# 1         Honda          Accord   17.5  Compact
# 2       Pontiac        Firebird   17.7   Sporty
# 3        Toyota           Camry   18.2  Midsize
# 4        Toyota          Celica   18.4   Sporty
# 5      Chrylser        Concorde   18.4    Large
# 6       Pontiac      Grand_Prix   18.5  Midsize
# 7     Chevrolet         Caprice   18.8    Large
# 8         Dodge         Caravan   19.0      Van
# 9         Mazda             MPV   19.1      Van
# 10       Nissan           Quest   19.1      Van
# 11        Eagle          Vision   19.3    Large
# 12       Subaru          Legacy   19.5  Compact
# 13   Oldsmobile      Silhouette   19.5      Van
# 14   Volkswagen         Eurovan   19.7      Van
# 15        Honda         Prelude   19.8   Sporty
# 16         Ford        Aerostar   19.9      Van
# 17   Volkswagen          Passat   20.0  Compact
# 18         Ford          Taurus   20.2  Midsize
# 19   Oldsmobile    Eighty-Eight   20.7    Large
# ...

# %% [markdown]
# ## 3. Find out top 7 most fuel economic cars for Highway

# %% [markdown]
# ##

# %%
seven_fuels_eco = df2.sort_values('MPG.highway',ascending=False)[['MPG.highway','Model','Type','Price']]

# %%
p =seven_fuels_eco.head(7)

# %%
p.index = range(1,8,1)

# %%
p
# Out:
#    MPG.highway   Model   Type  Price
# 1           50   Metro  Small    8.4
# 2           46   Civic  Small   12.1
# 3           43   Swift  Small    8.6
# 4           41  LeMans  Small    9.0
# 5           38      SL  Small   11.1
# 6           37  Tercel  Small    9.8
# 7           37   Justy  Small    8.4

# %% [markdown]
# ## 4. Find out Models of cars having no AirBags and which are of compact type whose price is below 20.

# %%
df2[(df2['Type']=='Compact') & (df2['AirBags']=='None') & (df2['Price']<20)][['Model','Type','AirBags','Price']]
# Out:
# Empty DataFrame
# Columns: [Model, Type, AirBags, Price]
# Index: []

# %%
df2
# Out:
#     id Manufacturer    Model     Type  Min.Price  Price  Max.Price  MPG.city  \
# 0    1        Acura  Integra    Small       12.9   15.9       18.8        25
# 1    2        Acura   Legend  Midsize       29.2   33.9       38.7        18
# 2    3         Audi       90  Compact       25.9   29.1       32.3        20
# 3    4         Audi      100  Midsize       30.8   37.7       44.6        19
# 4    5          BMW     535i  Midsize       23.7   30.0       36.2        22
# ..  ..          ...      ...      ...        ...    ...        ...       ...
# 88  89   Volkswagen  Eurovan      Van       16.6   19.7       22.7        17
# 89  90   Volkswagen   Passat  Compact       17.6   20.0       22.4        21
# 90  91   Volkswagen  Corrado   Sporty       22.9   23.3       23.7        18
# 91  92        Volvo      240  Compact       21.8   22.7       23.5        21
# 92  93        Volvo      850  Midsize       24.8   26.7       28.5        20
#
# ...

# %% [markdown]
# ## 5. Find out top 7 most fuel economic cars for city, show results in sorted manner based on Horsepower.

# %%
q = df2.sort_values('MPG.city',ascending=False)[['MPG.city','Horsepower','Manufacturer','Model']].head(7)
q.index = range(1,8,1)

# %%
q
# Out:
#    MPG.city  Horsepower Manufacturer    Model
# 1        46          55          Geo    Metro
# 2        42         102        Honda    Civic
# 3        39          70       Suzuki    Swift
# 4        33          73       Subaru    Justy
# 5        32          82       Toyota   Tercel
# 6        31          74      Pontiac   LeMans
# 7        31          63         Ford  Festiva

# %%
p = q.sort_values('Horsepower')

# %% [markdown]
# ## 6. Find out Cars having mileage of more than 15 miles in city

# %%
MPG = df2[df2['MPG.city']>15][['Manufacturer','Model','MPG.city']]

# %%
MPG.index = range(1,92,1)

# %%
MPG
# Out:
#    Manufacturer    Model  MPG.city
# 1         Acura  Integra        25
# 2         Acura   Legend        18
# 3          Audi       90        20
# 4          Audi      100        19
# 5           BMW     535i        22
# ..          ...      ...       ...
# 87   Volkswagen  Eurovan        17
# 88   Volkswagen   Passat        21
# 89   Volkswagen  Corrado        18
# 90        Volvo      240        21
# 91        Volvo      850        20
#
# [91 rows x 3 columns]

# %% [markdown]
# ## 7. Find out Cars with US based origin.

# %%
USBO = df2[df2['Origin']=='USA'][['Manufacturer','Model','Origin']]
USBO.index = range(1,49,1)

# %%
USBO
# Out:
#    Manufacturer           Model Origin
# 1         Buick         Century    USA
# 2         Buick         LeSabre    USA
# 3         Buick      Roadmaster    USA
# 4         Buick         Riviera    USA
# 5      Cadillac         DeVille    USA
# 6      Cadillac         Seville    USA
# 7     Chevrolet        Cavalier    USA
# 8     Chevrolet         Corsica    USA
# 9     Chevrolet          Camaro    USA
# 10    Chevrolet          Lumina    USA
# 11    Chevrolet      Lumina_APV    USA
# 12    Chevrolet           Astro    USA
# 13    Chevrolet         Caprice    USA
# 14    Chevrolet        Corvette    USA
# 15     Chrylser        Concorde    USA
# 16     Chrysler         LeBaron    USA
# 17     Chrysler        Imperial    USA
# 18        Dodge            Colt    USA
# 19        Dodge          Shadow    USA
# 20        Dodge          Spirit    USA
# 21        Dodge         Caravan    USA
# 22        Dodge         Dynasty    USA
# 23        Dodge         Stealth    USA
# ...

# %% [markdown]
# ## 8. Find out Cars with no airbags and which are compact in type, from the output retrieve only Model, Mileage in city, Type, Airbags
